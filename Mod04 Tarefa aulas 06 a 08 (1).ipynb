# %% [markdown]
# # Tarefa 03
#
# - Leia os enunciados com atenção
# - Saiba que pode haver mais de uma resposta correta
# - Insira novas células de código sempre que achar necessário
# - Em caso de dúvidas, procure os Tutores
# - Divirta-se :)

# %%
import pandas as pd
import requests

# %% [markdown]
# ####  1) Lendo de APIs
# Vimos em aula como carregar dados públicos do governo através de um API (*Application Programming Interface*). No exemplo de aula, baixamos os dados de pedidos de verificação de limites (PVL) realizados por estados, e selecionamos apenas aqueles referentes ao estado de São Paulo.
#
# 1. Repita os mesmos passos feitos em aula, mas selecione os PVLs realizados por municípios no estado do Rio de Janeiro.
# 2. Quais são os três *status* das solicitações mais frequentes na base? Quais são suas frequências?
# 3. Construa uma nova variável que contenha o ano do **status**. Observe que ```data_status``` vem como tipo *object* no **DataFrame**. Dica: você pode usar o método ```.str``` para transformar o tipo da variável em string, em seguida um método como [**slice()**](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.slice.html) ou [**split()**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.split.html).
# 4. Indique a frequência de cada ano do campo construído no item (3).

# %%
# 1) Seu código aqui
url = 'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf=RJ&tipo_interessado=Munic%C3%ADpio'

# %%
r = requests.get(url)

# %%
r.status_code
# Out:
# 200

# %%
data_json = r.json()

# %%
print(data_json['items'])
# Out:
# [{'id_pleito': 10478, 'tipo_interessado': 'Município', 'interessado': 'Duque de Caxias', 'cod_ibge': 3301702, 'uf': 'RJ', 'num_pvl': None, 'status': 'Regularizado', 'num_processo': '17944.001209/2012-85', 'data_protocolo': '2020-04-13T03:00:00Z', 'tipo_operacao': 'Operação contratual interna', 'finalidade': 'Regularização de Dívida - Outros', 'tipo_credor': 'Instituição Financeira Nacional', 'credor': 'Banco do Brasil S/A', 'moeda': 'Real', 'valor': 149768343.08, 'pvl_assoc_divida': 0, 'pvl_contradado_credor': 0, 'data_status': '29/05/2020'}, {'id_pleito': 47509, 'tipo_interessado': 'Município', 'interessado': 'Casimiro de Abreu', 'cod_ibge': 3301306, 'uf': 'RJ', 'num_pvl': 'PVL02.002362/2021-58', 'status': 'Deferido', 'num_processo': '17944.103628/2021-41', 'data_protocolo': '2021-12-24T15:46:02Z', 'tipo_operacao': 'Operação contratual interna', 'finalidade': 'Infraestrutura', 'tipo_credor': 'Instituição Financeira Nacional', 'credor': 'Caixa Econômica Federal', 'moeda': 'Real', 'va
# ...

# %%
df=pd.DataFrame(data_json['items'])
df
# Out:
#      id_pleito tipo_interessado        interessado  cod_ibge  uf  \
# 0        10478        Município    Duque de Caxias   3301702  RJ
# 1        47509        Município  Casimiro de Abreu   3301306  RJ
# 2        42271        Município     Barra do Piraí   3300308  RJ
# 3        13443        Município        Nova Iguaçu   3303500  RJ
# 4        11419        Município     Rio de Janeiro   3304557  RJ
# ..         ...              ...                ...       ...  ..
# 237      42266        Município    Paty do Alferes   3303856  RJ
# 238      36529        Município            Resende   3304201  RJ
# 239       8839        Município        Porciúncula   3304102  RJ
# 240      61653        Município        Teresópolis   3305802  RJ
# 241      60057        Município             Paraty   3303807  RJ
#
#                   num_pvl                                             status  \
# 0                    None                                       Regularizado
# ...

# %%
# 2) Seu código aqui
df['status'].unique()
# Out:
# array(['Regularizado', 'Deferido',
#        'Encaminhado à PGFN com manifestação técnica favorável',
#        'Em análise', 'Arquivado', 'Arquivado por decurso de prazo',
#        'Deferido (PVL-IF)', 'Arquivado a pedido',
#        'Em retificação pelo interessado',
#        'Em retificação pelo interessado (PVL-IF)',
#        'Em retificação pelo credor'], dtype=object)

# %%
df['status'].value_counts().head(3)
# Out:
# Deferido        96
# Arquivado       53
# Regularizado    26
# Name: status, dtype: int64

# %%
df['status'].value_counts(normalize=True).head(3) * 100
# Out:
# Deferido        39.669421
# Arquivado       21.900826
# Regularizado    10.743802
# Name: status, dtype: float64

# %%
# 3) Seu código aqui
df.dtypes
# Out:
# id_pleito                  int64
# tipo_interessado          object
# interessado               object
# cod_ibge                   int64
# uf                        object
# num_pvl                   object
# status                    object
# num_processo              object
# data_protocolo            object
# tipo_operacao             object
# finalidade                object
# tipo_credor               object
# credor                    object
# moeda                     object
# valor                    float64
# pvl_assoc_divida           int64
# pvl_contradado_credor      int64
# data_status               object
# dtype: object

# %%
df['Ano'] = df['data_status'].str.split('/').str[-1]
df
# Out:
#      id_pleito tipo_interessado        interessado  cod_ibge  uf  \
# 0        10478        Município    Duque de Caxias   3301702  RJ
# 1        47509        Município  Casimiro de Abreu   3301306  RJ
# 2        42271        Município     Barra do Piraí   3300308  RJ
# 3        13443        Município        Nova Iguaçu   3303500  RJ
# 4        11419        Município     Rio de Janeiro   3304557  RJ
# ..         ...              ...                ...       ...  ..
# 237      42266        Município    Paty do Alferes   3303856  RJ
# 238      36529        Município            Resende   3304201  RJ
# 239       8839        Município        Porciúncula   3304102  RJ
# 240      61653        Município        Teresópolis   3305802  RJ
# 241      60057        Município             Paraty   3303807  RJ
#
#                   num_pvl                                             status  \
# 0                    None                                       Regularizado
# ...

# %% [markdown]
# ####  2) Melhorando a interação com o API
# Observe dois URLs de consultas diferentes, por exemplo o URL utilizado em aula, e o URL feito no exercício anterior. Compare-os e observe as diferenças.
#
# 1. Faça uma função em Python que recebe como argumento o UF da consulta e o tipo de interessado (```'Estado'```ou ```Município```), e que devolve os dados da consulta no formato *DataFrame*.
# 2. Quantas solicitações para o Estado podem ser consultadas para Minas Gerais com *status* em 'Arquivado por decurso de prazo' estão registradas?
# 3. Qual é o município da Bahia com mais solicitações deferidas?
# 4. Salve um arquivo .csv com os dados de solicitações da Bahia, com interessado = 'Estado'

# %%
#1) Seu código aqui

def consultar_dados(uf, tipo_interessado):
    # Construir a URL de consulta
    base_url = 'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl'
    params = {'uf': uf, 'tipo_interessado': tipo_interessado}
    
    # Fazer a requisição HTTP
    response = requests.get(base_url, params=params)
    
    # Verificar se a requisição foi bem sucedida
    if response.status_code == 200:
        # Converter os dados JSON em DataFrame
        print('Consulta realizada.')
        data = response.json()
        df = pd.DataFrame(data['items'])
        return df
    else:
        print('Erro ao realizar a consulta.')
        return None

# %%
consultar_dados('MG','Estado')
# Out:
#     id_pleito tipo_interessado   interessado  cod_ibge  uf  \
# 0       13441           Estado  Minas Gerais        31  MG
# 1       13587           Estado  Minas Gerais        31  MG
# 2       13695           Estado  Minas Gerais        31  MG
# 3       13672           Estado  Minas Gerais        31  MG
# 4        9197           Estado  Minas Gerais        31  MG
# 5        7032           Estado  Minas Gerais        31  MG
# 6       11571           Estado  Minas Gerais        31  MG
# 7       13275           Estado  Minas Gerais        31  MG
# 8       11696           Estado  Minas Gerais        31  MG
# 9       12286           Estado  Minas Gerais        31  MG
# 10       7023           Estado  Minas Gerais        31  MG
# 11      13641           Estado  Minas Gerais        31  MG
# 12      10294           Estado  Minas Gerais        31  MG
# 13       8255           Estado  Minas Gerais        31  MG
# 14       7419           Estado  Minas Gerais        31  MG
# ...

# %%
# 2) Seu código aqui
df_estado_mg = consultar_dados('MG', 'Estado')

# %%
df_estado_mg
# Out:
#     id_pleito tipo_interessado   interessado  cod_ibge  uf  \
# 0       13441           Estado  Minas Gerais        31  MG
# 1       13587           Estado  Minas Gerais        31  MG
# 2       13695           Estado  Minas Gerais        31  MG
# 3       13672           Estado  Minas Gerais        31  MG
# 4        9197           Estado  Minas Gerais        31  MG
# 5        7032           Estado  Minas Gerais        31  MG
# 6       11571           Estado  Minas Gerais        31  MG
# 7       13275           Estado  Minas Gerais        31  MG
# 8       11696           Estado  Minas Gerais        31  MG
# 9       12286           Estado  Minas Gerais        31  MG
# 10       7023           Estado  Minas Gerais        31  MG
# 11      13641           Estado  Minas Gerais        31  MG
# 12      10294           Estado  Minas Gerais        31  MG
# 13       8255           Estado  Minas Gerais        31  MG
# 14       7419           Estado  Minas Gerais        31  MG
# ...

# %%
df_estado_mg['status'].value_counts()
# Out:
# Encaminhado à PGFN com manifestação técnica favorável    20
# Deferido                                                  7
# Arquivado a pedido                                        5
# Arquivado                                                 3
# Arquivado pela STN                                        3
# Indeferido                                                1
# Arquivado por decurso de prazo                            1
# Name: status, dtype: int64

# %%
df_estado_mg[df_estado_mg['status'] == 'Arquivado por decurso de prazo']['status'].value_counts()
# Out:
# Arquivado por decurso de prazo    1
# Name: status, dtype: int64

# %%
# 3) Seu código aqui
df_municipio_ba = consultar_dados('BA', 'Município')
# Out:
# Consulta realizada.

# %%
df_municipio_ba
# Out:
#      id_pleito tipo_interessado           interessado  cod_ibge  uf  \
# 0        46558        Município  Conceição do Almeida   2908309  BA
# 1        34577        Município             Barreiras   2903201  BA
# 2        38708        Município       Morro do Chapéu   2921708  BA
# 3        39950        Município              Barrocas   2903276  BA
# 4        42636        Município          Castro Alves   2907301  BA
# ..         ...              ...                   ...       ...  ..
# 906       6562        Município                Mucugê   2921906  BA
# 907       6209        Município           Sátiro Dias   2929701  BA
# 908      12058        Município               Itiruçu   2916906  BA
# 909       6710        Município                 Cocos   2908101  BA
# 910       6955        Município              Jacobina   2917508  BA
#
#                   num_pvl                                             status  \
# ...

# %%
df_municipio_ba[df_municipio_ba['status'] == 'Deferido']['interessado'].value_counts().head(1)
# Out:
# Luís Eduardo Magalhães    15
# Name: interessado, dtype: int64

# %%
# 4) Seu código aqui
consultar_dados('BA', 'Estado').to_csv('df_estado_ba.csv',index=False)
# Out:
# Consulta realizada.
